# %%
#SIFT=Scale-Invariaant feature transform
#orb=orient fast and roatated Brief
#surf=speeded up robust features


import cv2
import matplotlib.pyplot as plt
from google.colab import files



uploaded=files.upload()
image_path=list(uploaded.keys())[0]
print("Img loaded",image_path)


img=cv2.imread(image_path)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


plt.figure(figsize=(6,6))
plt.imshow(gray,cmap='gray')
plt.title("Input Image")
plt.axis("off")
plt.show()



orb=cv2.ORB_create(nfeatures=500)



kp_orb,des_orb=orb.detectAndCompute(gray,None)
orb_img=cv2.drawKeypoints(
    gray,kp_orb,None,
    flags=cv2.DrawMatchesFlags_DEFAULT
)


plt.figure(figsize=(6,6))
plt.imshow(orb_img,cmap='gray')
plt.title(f"orb feature detection :{len(kp_orb)}")
plt.axis("off")
plt.show()
print("ORB decscription ",des.)
